# %%
import pandas as pd 
import os
from pathlib import Path
import csv
import shutil
from tempfile import NamedTemporaryFile

# %% [markdown]
# #### Ouverture des plusieurs fichiers à rassembler dans un dictionnaire

# %%
csvDict = {}

for subdir, dirs, files in os.walk(r'Datasets/'):
    for filename in files:
        filepath = subdir + os.sep + filename
        if filepath.endswith(".csv"):
            #if "MN5_AROME" in filename:
            if "drivers.csv" == filename:
                csvDict[filename[:-4]] = pd.read_csv(Path(filepath), sep=",")
            if "driver_standings.csv" == filename:
                csvDict[filename[:-4]] = pd.read_csv(Path(filepath), sep=",")
            if "results.csv" == filename:
                csvDict[filename[:-4]] = pd.read_csv(Path(filepath), sep=",")
            if "status.csv" == filename:
                csvDict[filename[:-4]] = pd.read_csv(Path(filepath), sep=",")
            if "constructors.csv" == filename:
                csvDict[filename[:-4]] = pd.read_csv(Path(filepath), sep=",")
            if "races.csv" == filename:
                csvDict[filename[:-4]] = pd.read_csv(Path(filepath), sep=",")
            if "circuits.csv" == filename:
                csvDict[filename[:-4]] = pd.read_csv(Path(filepath), sep=",")
for i in csvDict.keys():
    print (i)
# Out:
# circuits
# constructors
# drivers
# driver_standings
# races
# results
# status

# %% [markdown]
# #### Affichage de chaque colonne de chaque fichier

# %%
for dataset in csvDict:
    print("---", dataset)
    for col in csvDict[dataset]:
        print(col)
# Out:
# --- circuits
# circuitId
# circuitRef
# name
# location
# country
# lat
# lng
# alt
# url
# --- constructors
# constructorId
# constructorRef
# name
# nationality
# url
# --- drivers
# driverId
# driverRef
# number
# code
# forename
# surname
# dob
# nationality
# url
# --- driver_standings
# driverStandingsId
# raceId
# driverId
# points
# position
# positionText
# wins
# --- races
# raceId
# year
# round
# circuitId
# name
# date
# time
# url
# --- results
# resultId
# raceId
# driverId
# constructorId
# number
# grid
# position
# positionText
# positionOrder
# points
# laps
# time
# milliseconds
# fastestLap
# rank
# fastestLapTime
# fastestLapSpeed
# statusId
# --- status
# statusId
# status

# %% [markdown]
# #### Suppression de colonnes inutiles dans les différents fichiers

# %%
drivers = csvDict["drivers"]
drivers = drivers.drop(columns = ["url"])
drivers = drivers.rename(columns = {'number':'pilot_number'})
drivers
# Out:
#      driverId   driverRef pilot_number code   forename     surname  \
# 0           1    hamilton           44  HAM      Lewis    Hamilton
# 1           2    heidfeld           \N  HEI       Nick    Heidfeld
# 2           3     rosberg            6  ROS       Nico     Rosberg
# 3           4      alonso           14  ALO   Fernando      Alonso
# 4           5  kovalainen           \N  KOV     Heikki  Kovalainen
# ..        ...         ...          ...  ...        ...         ...
# 843       845    sirotkin           35  SIR     Sergey    Sirotkin
# 844       846      norris            4  NOR      Lando      Norris
# 845       847     russell           63  RUS     George     Russell
# 846       848       albon           23  ALB  Alexander       Albon
# 847       849      latifi            6  LAT   Nicholas      Latifi
#
#             dob nationality
# 0    1985-01-07     British
# 1    1977-05-10      German
# 2    1985-06-27      German
# 3    1981-07-29     Spanish
# ...

# %%
driver_standings = csvDict["driver_standings"]
driver_standings = driver_standings.drop(columns = ["driverStandingsId"])
driver_standings
# Out:
#        raceId  driverId  points  position positionText  wins
# 0          18         1    10.0         1            1     1
# 1          18         2     8.0         2            2     0
# 2          18         3     6.0         3            3     0
# 3          18         4     5.0         4            4     0
# 4          18         5     4.0         5            5     0
# ...       ...       ...     ...       ...          ...   ...
# 32684    1036       825     1.0        17           17     0
# 32685    1036       840    40.0         5            5     0
# 32686    1036       817    20.0        10           10     0
# 32687    1036       830    95.0         2            2     1
# 32688    1036       807     6.0        14           14     0
#
# [32689 rows x 6 columns]

# %%
results = csvDict["results"]
results
# Out:
#        resultId  raceId  driverId  constructorId number  grid position  \
# 0             1      18         1              1     22     1        1
# 1             2      18         2              2      3     5        2
# 2             3      18         3              3      7     7        3
# 3             4      18         4              4      5    11        4
# 4             5      18         5              1     23     3        5
# ...         ...     ...       ...            ...    ...   ...      ...
# 24735     24741    1036       841             51     99    20       16
# 24736     24742    1036       847              3     63    18       17
# 24737     24743    1036       849              3      6    19       18
# 24738     24744    1036       154            210      8    17       19
# 24739     24745    1036       844              6     16     9       \N
#
#       positionText  positionOrder  points  laps         time milliseconds  \
# ...

# %%
results = results.drop(columns =["position", "positionText", "fastestLap", "fastestLapTime", "fastestLapSpeed", "milliseconds", "resultId"])
results
# Out:
#        raceId  driverId  constructorId number  grid  positionOrder  points  \
# 0          18         1              1     22     1              1    10.0
# 1          18         2              2      3     5              2     8.0
# 2          18         3              3      7     7              3     6.0
# 3          18         4              4      5    11              4     5.0
# 4          18         5              1     23     3              5     4.0
# ...       ...       ...            ...    ...   ...            ...     ...
# 24735    1036       841             51     99    20             16     0.0
# 24736    1036       847              3     63    18             17     0.0
# 24737    1036       849              3      6    19             18     0.0
# 24738    1036       154            210      8    17             19     0.0
# 24739    1036       844              6     16     9             20     0.0
#
#        laps         time rank  statusId
# ...

# %%
status = csvDict["status"]
status
# Out:
#      statusId        status
# 0           1      Finished
# 1           2  Disqualified
# 2           3      Accident
# 3           4     Collision
# 4           5        Engine
# ..        ...           ...
# 130       133      +49 Laps
# 131       134      +38 Laps
# 132       135    Brake duct
# 133       136          Seat
# 134       137        Damage
#
# [135 rows x 2 columns]

# %% [markdown]
# #### Création d'un index commun

# %%
drivers = drivers.set_index("driverId")
results = results.set_index("driverId")
drivers
# Out:
#            driverRef pilot_number code   forename     surname         dob  \
# driverId
# 1           hamilton           44  HAM      Lewis    Hamilton  1985-01-07
# 2           heidfeld           \N  HEI       Nick    Heidfeld  1977-05-10
# 3            rosberg            6  ROS       Nico     Rosberg  1985-06-27
# 4             alonso           14  ALO   Fernando      Alonso  1981-07-29
# 5         kovalainen           \N  KOV     Heikki  Kovalainen  1981-10-19
# ...              ...          ...  ...        ...         ...         ...
# 845         sirotkin           35  SIR     Sergey    Sirotkin  1995-08-27
# 846           norris            4  NOR      Lando      Norris  1999-11-13
# 847          russell           63  RUS     George     Russell  1998-02-15
# 848            albon           23  ALB  Alexander       Albon  1996-03-23
# 849           latifi            6  LAT   Nicholas      Latifi  1995-06-29
#
#          nationality
# driverId
# 1            British
# ...

# %%
results
# Out:
#           raceId  constructorId number  grid  positionOrder  points  laps  \
# driverId
# 1             18              1     22     1              1    10.0    58
# 2             18              2      3     5              2     8.0    58
# 3             18              3      7     7              3     6.0    58
# 4             18              4      5    11              4     5.0    58
# 5             18              1     23     3              5     4.0    58
# ...          ...            ...    ...   ...            ...     ...   ...
# 841         1036             51     99    20             16     0.0    65
# 847         1036              3     63    18             17     0.0    65
# 849         1036              3      6    19             18     0.0    64
# 154         1036            210      8    17             19     0.0    64
# 844         1036              6     16     9             20     0.0    38
#
#                  time rank  statusId
# driverId
# ...

# %% [markdown]
# #### Fusion entre drivers et results

# %%
driverGen = drivers.join(results)
driverGen
# Out:
#          driverRef pilot_number code  forename   surname         dob  \
# driverId
# 1         hamilton           44  HAM     Lewis  Hamilton  1985-01-07
# 1         hamilton           44  HAM     Lewis  Hamilton  1985-01-07
# 1         hamilton           44  HAM     Lewis  Hamilton  1985-01-07
# 1         hamilton           44  HAM     Lewis  Hamilton  1985-01-07
# 1         hamilton           44  HAM     Lewis  Hamilton  1985-01-07
# ...            ...          ...  ...       ...       ...         ...
# 849         latifi            6  LAT  Nicholas    Latifi  1995-06-29
# 849         latifi            6  LAT  Nicholas    Latifi  1995-06-29
# 849         latifi            6  LAT  Nicholas    Latifi  1995-06-29
# 849         latifi            6  LAT  Nicholas    Latifi  1995-06-29
# 849         latifi            6  LAT  Nicholas    Latifi  1995-06-29
#
#          nationality  raceId  constructorId number  grid  positionOrder  \
# driverId
# ...

# %% [markdown]
# #### Suppression des colonnes superflue

# %%
#driverGen = driverGen.drop(columns = ["driverRef", "code", "position", "positionText"])
#driverGen = driverGen.rename(columns = {'number':'pilot_number'})
#driverGen

# %% [markdown]
# #### Reset de l'index

# %%
driverGen = driverGen.reset_index()
driverGen
# Out:
#        driverId driverRef pilot_number code  forename   surname         dob  \
# 0             1  hamilton           44  HAM     Lewis  Hamilton  1985-01-07
# 1             1  hamilton           44  HAM     Lewis  Hamilton  1985-01-07
# 2             1  hamilton           44  HAM     Lewis  Hamilton  1985-01-07
# 3             1  hamilton           44  HAM     Lewis  Hamilton  1985-01-07
# 4             1  hamilton           44  HAM     Lewis  Hamilton  1985-01-07
# ...         ...       ...          ...  ...       ...       ...         ...
# 24735       849    latifi            6  LAT  Nicholas    Latifi  1995-06-29
# 24736       849    latifi            6  LAT  Nicholas    Latifi  1995-06-29
# 24737       849    latifi            6  LAT  Nicholas    Latifi  1995-06-29
# 24738       849    latifi            6  LAT  Nicholas    Latifi  1995-06-29
# 24739       849    latifi            6  LAT  Nicholas    Latifi  1995-06-29
#
# ...

# %% [markdown]
# #### Lier les pilotes à leur résultat en course avec leur statusID (présent dans le dataset status)

# %%
status = status.set_index("statusId")
driverGen = driverGen.set_index("statusId")
driverGen = driverGen.join(status)
driverGen
# Out:
#           driverId  driverRef pilot_number code forename    surname  \
# statusId
# 1                1   hamilton           44  HAM    Lewis   Hamilton
# 1                1   hamilton           44  HAM    Lewis   Hamilton
# 1                1   hamilton           44  HAM    Lewis   Hamilton
# 1                1   hamilton           44  HAM    Lewis   Hamilton
# 1                1   hamilton           44  HAM    Lewis   Hamilton
# ...            ...        ...          ...  ...      ...        ...
# 132            813  maldonado           13  MAL   Pastor  Maldonado
# 132            821  gutierrez           21  GUT  Esteban  Gutiérrez
# 135              8  raikkonen            7  RAI     Kimi  Räikkönen
# 136            815      perez           11  PER   Sergio      Pérez
# 137            817  ricciardo            3  RIC   Daniel  Ricciardo
#
#                  dob nationality  raceId  constructorId number  grid  \
# statusId
# ...

# %%
driverGen = driverGen.reset_index()
driverGen
# Out:
#        statusId  driverId  driverRef pilot_number code forename    surname  \
# 0             1         1   hamilton           44  HAM    Lewis   Hamilton
# 1             1         1   hamilton           44  HAM    Lewis   Hamilton
# 2             1         1   hamilton           44  HAM    Lewis   Hamilton
# 3             1         1   hamilton           44  HAM    Lewis   Hamilton
# 4             1         1   hamilton           44  HAM    Lewis   Hamilton
# ...         ...       ...        ...          ...  ...      ...        ...
# 24735       132       813  maldonado           13  MAL   Pastor  Maldonado
# 24736       132       821  gutierrez           21  GUT  Esteban  Gutiérrez
# 24737       135         8  raikkonen            7  RAI     Kimi  Räikkönen
# 24738       136       815      perez           11  PER   Sergio      Pérez
# 24739       137       817  ricciardo            3  RIC   Daniel  Ricciardo
#
#               dob nationality  raceId  constructorId number  grid  \
# ...

# %%
driverGen = driverGen.drop(columns = ["statusId"])
driverGen = driverGen.set_index("driverId")
driverGen
# Out:
#           driverRef pilot_number code forename    surname         dob  \
# driverId
# 1          hamilton           44  HAM    Lewis   Hamilton  1985-01-07
# 1          hamilton           44  HAM    Lewis   Hamilton  1985-01-07
# 1          hamilton           44  HAM    Lewis   Hamilton  1985-01-07
# 1          hamilton           44  HAM    Lewis   Hamilton  1985-01-07
# 1          hamilton           44  HAM    Lewis   Hamilton  1985-01-07
# ...             ...          ...  ...      ...        ...         ...
# 813       maldonado           13  MAL   Pastor  Maldonado  1985-03-09
# 821       gutierrez           21  GUT  Esteban  Gutiérrez  1991-08-05
# 8         raikkonen            7  RAI     Kimi  Räikkönen  1979-10-17
# 815           perez           11  PER   Sergio      Pérez  1990-01-26
# 817       ricciardo            3  RIC   Daniel  Ricciardo  1989-07-01
#
#          nationality  raceId  constructorId number  grid  positionOrder  \
# driverId
# ...

# %%
driverGen = driverGen.reset_index()

# %% [markdown]
# #### Lier le fichier driver avec le nom des constructeurs

# %%
constructors = csvDict["constructors"]
constructors = constructors.drop(columns = ["url", "constructorRef"])
constructors = constructors.rename(columns = {'nationality':'constructor_nationality', 'name':'constructor_name'})
constructors = constructors.set_index("constructorId")
driverGen = driverGen.set_index("constructorId")
constructors
# Out:
#                    constructor_name constructor_nationality
# constructorId
# 1                           McLaren                 British
# 2                        BMW Sauber                  German
# 3                          Williams                 British
# 4                           Renault                  French
# 5                        Toro Rosso                 Italian
# ...                             ...                     ...
# 209                  Manor Marussia                 British
# 210                    Haas F1 Team                American
# 211                    Racing Point                 British
# 212            Scuderia Alpha Tauri                 Italian
# 213                      AlphaTauri                 Italian
#
# [211 rows x 2 columns]

# %%
driverGen = driverGen.join(constructors)
driverGen
# Out:
#                driverId driverRef pilot_number code forename   surname  \
# constructorId
# 1                     1  hamilton           44  HAM    Lewis  Hamilton
# 1                     1  hamilton           44  HAM    Lewis  Hamilton
# 1                     1  hamilton           44  HAM    Lewis  Hamilton
# 1                     1  hamilton           44  HAM    Lewis  Hamilton
# 1                     1  hamilton           44  HAM    Lewis  Hamilton
# ...                 ...       ...          ...  ...      ...       ...
# 213                 826     kvyat           26  KVY   Daniil     Kvyat
# 213                 826     kvyat           26  KVY   Daniil     Kvyat
# 213                 842     gasly           10  GAS   Pierre     Gasly
# 213                 842     gasly           10  GAS   Pierre     Gasly
# 213                 826     kvyat           26  KVY   Daniil     Kvyat
#
#                       dob nationality  raceId number  grid  positionOrder  \
# constructorId
# ...

# %%
driverGen = driverGen.reset_index()
driverGen = driverGen.set_index("raceId")
driverGen
# Out:
#         constructorId  driverId driverRef pilot_number code forename  \
# raceId
# 18                  1         1  hamilton           44  HAM    Lewis
# 19                  1         1  hamilton           44  HAM    Lewis
# 21                  1         1  hamilton           44  HAM    Lewis
# 22                  1         1  hamilton           44  HAM    Lewis
# 23                  1         1  hamilton           44  HAM    Lewis
# ...               ...       ...       ...          ...  ...      ...
# 1033              213       826     kvyat           26  KVY   Daniil
# 1036              213       826     kvyat           26  KVY   Daniil
# 1032              213       842     gasly           10  GAS   Pierre
# 1036              213       842     gasly           10  GAS   Pierre
# 1031              213       826     kvyat           26  KVY   Daniil
#
#          surname         dob nationality number  grid  positionOrder  points  \
# raceId
# ...

# %% [markdown]
# #### Associer le raceId à la course correspondante

# %%
races = csvDict["races"]
races = races.rename(columns = {'name':'race_name', 'date':'race_date', 'time':'race_start_time'})
races = races.drop(columns = ["url"])
races = races.set_index("raceId")
races
# Out:
#         year  round  circuitId                  race_name   race_date  \
# raceId
# 1       2009      1          1      Australian Grand Prix  2009-03-29
# 2       2009      2          2       Malaysian Grand Prix  2009-04-05
# 3       2009      3         17         Chinese Grand Prix  2009-04-19
# 4       2009      4          3         Bahrain Grand Prix  2009-04-26
# 5       2009      5          4         Spanish Grand Prix  2009-05-10
# ...      ...    ...        ...                        ...         ...
# 1039    2020      9         76          Tuscan Grand Prix  2020-09-13
# 1040    2020     10         71         Russian Grand Prix  2020-09-27
# 1041    2020     11         20           Eifel Grand Prix  2020-10-11
# 1042    2020     12         75      Portuguese Grand Prix  2020-10-25
# 1043    2020     13         21  Emilia Romagna Grand Prix  2020-11-01
#
#        race_start_time
# raceId
# 1             06:00:00
# 2             09:00:00
# 3             07:00:00
# ...

# %%
driverGen = driverGen.join(races)
driverGen = driverGen.reset_index()
driverGen
# Out:
#        raceId  constructorId  driverId   driverRef pilot_number code forename  \
# 0           1              1         1    hamilton           44  HAM    Lewis
# 1           1              1         5  kovalainen           \N  KOV   Heikki
# 2           1              2         2    heidfeld           \N  HEI     Nick
# 3           1              2         9      kubica           88  KUB   Robert
# 4           1              3         3     rosberg            6  ROS     Nico
# ...       ...            ...       ...         ...          ...  ...      ...
# 24735    1036            210       154    grosjean            8  GRO   Romain
# 24736    1036            211       815       perez           11  PER   Sergio
# 24737    1036            211       840      stroll           18  STR    Lance
# 24738    1036            213       826       kvyat           26  KVY   Daniil
# 24739    1036            213       842       gasly           10  GAS   Pierre
#
# ...

# %% [markdown]
# #### Associer le circuitId au circuit correspondant

# %%
circuits = csvDict["circuits"]
circuits = circuits.drop(columns = ["lat","lng","alt","url","circuitRef"])
circuits = circuits.rename(columns = {'name':'circuit_name'})
circuits
# Out:
#     circuitId                          circuit_name      location     country
# 0           1        Albert Park Grand Prix Circuit     Melbourne   Australia
# 1           2          Sepang International Circuit  Kuala Lumpur    Malaysia
# 2           3         Bahrain International Circuit        Sakhir     Bahrain
# 3           4        Circuit de Barcelona-Catalunya      Montmeló       Spain
# 4           5                         Istanbul Park      Istanbul      Turkey
# ..        ...                                   ...           ...         ...
# 71         72          Port Imperial Street Circuit    New Jersey         USA
# 72         73                     Baku City Circuit          Baku  Azerbaijan
# 73         74                  Hanoi Street Circuit         Hanoi     Vietnam
# 74         75    Autódromo Internacional do Algarve      Portimão    Portugal
# 75         76  Autodromo Internazionale del Mugello       Mugello       Italy
#
# [76 rows x 4 columns]

# %%
circuits = circuits.set_index("circuitId")
driverGen = driverGen.set_index("circuitId")
driverGen = driverGen.join(circuits)
driverGen = driverGen.reset_index()
driverGen = driverGen.drop(columns = ["circuitId", "raceId", "constructorId"])
driverGen = driverGen.set_index("driverId")
driverGen
# Out:
#                 driverRef pilot_number code  forename     surname         dob  \
# driverId
# 1                hamilton           44  HAM     Lewis    Hamilton  1985-01-07
# 5              kovalainen           \N  KOV    Heikki  Kovalainen  1981-10-19
# 2                heidfeld           \N  HEI      Nick    Heidfeld  1977-05-10
# 9                  kubica           88  KUB    Robert      Kubica  1984-12-07
# 3                 rosberg            6  ROS      Nico     Rosberg  1985-06-27
# ...                   ...          ...  ...       ...         ...         ...
# 822                bottas           77  BOT  Valtteri      Bottas  1989-08-28
# 825       kevin_magnussen           20  MAG     Kevin   Magnussen  1992-10-05
# 154              grosjean            8  GRO    Romain    Grosjean  1986-04-17
# 815                 perez           11  PER    Sergio       Pérez  1990-01-26
# 840                stroll           18  STR     Lance      Stroll  1998-10-29
#
# ...

# %% [markdown]
# #### Enregistrer le fichier CSV

# %%
driverGen.to_csv("Driver/driversGen.csv", sep=';')
